# %% [markdown]
# <a href="https://colab.research.google.com/github/leejineun/ai-class/blob/main/6_pretrained_%EC%88%98%EC%97%85%EC%9A%A9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # LeNet
# - CNN계의 고전
# - 우편번호와 수표의 필기체를 인식하기 위해 만든 단순한 구조의 모델

# %% [markdown]
# # AlexNet
#
# - 2012 ImageNet 우승 모델
# - 이미지 인식 방식을 DL로 전환
# - 5개의 convolution layer, 3개의 FC layer

# %% [markdown]
# # InceptionV3
# - 가장 많이 사용하는 모델 중 하나
# - 비대칭 합성곱을 사용하여 연산량 줄임
# - 보조 분류기 사용

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# <출처 : http://solarisailab.com/archives/1422>

# %% [markdown]
# # VGGNET
#
# - 2014년 ImageNet 준우승
# - 옥스포드 대학의 연구팀에서 개발
# - 16개 또는 19개 층으로 구성된 모델을 주로 사용 (VGG16, VGG19)
# - VGGNET을 기점으로 레이어가 급격히 증가

# %% [markdown]
# ### VGGNET 구조
# ![image.png](data:image/png;base64,...)
#
# <출처 - https://www.datamaker.io/posts/35/>

# %% [markdown]
# ### 작은 필터로 여러 번 컨볼루션 하는 것이 큰 필터로 한 번 하는 것보다 나은 점
# - 작은 필터로 여러번 할 경우 가중치가 더 적다
# - 가중치가 많으면 훈련시켜야 할 가중치가 많다는 의미
# - 즉, 학습 속도가 느려진다.
# - 또한 필터가 작아서 층이 늘어나면 특성에 비선형성을 증가시켜 데이터 특성이 점점 더 유용해진다

# %% [markdown]
# # RESNET
# - skip connection
#     - 한 레이어의 결과를 몇개의 레이어를 건너뛰고 다음 레이어에 추가
# - Residual Block
#     - 기존에 학습된 내용은 두고, 새롭게 학습해야 할 정보만 학습

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# <출처 :ㅣhttps://towardsdatascience.com/review-resnet-winner-of-ilsvrc-2015-image-classification-localization-detection-e39402bfa5d8>

# %% [markdown]
# # MobileNet
# - 모바일 디바이스에서도 사용가능하게 만든 모델
# - Depthwise Convolution과 1x1 Convolution을 사용하여 연산량을 줄임

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# <출처 : https://machinethink.net/blog/mobilenet-v2/>
